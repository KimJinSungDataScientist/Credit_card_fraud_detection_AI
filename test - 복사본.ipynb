# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch import autograd, optim
from torch.utils.data import DataLoader, Dataset

import torchvision
from torchvision.datasets import MNIST
from torchvision import transforms
from torchvision.utils import save_image
from tensorboardX import SummaryWriter

import numpy as np
import matplotlib.pyplot as plt
import random

torch.manual_seed(0)
np.random.seed(0)
torch.backends.cudnn.benchmark = True
torch.backends.cudnn.determinstic = False

writer = SummaryWriter(logdir='runs/GAN_training')
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
def imshow_grid(img):
    img = torchvision.utils.make_grid(img.cpu().detach())
    img_numpy = img.numpy()
    print(img_numpy.shape)
    plt.figure(figsize=(10, 20))
    plt.imshow(np.transpose(img_numpy, (1, 2, 0)))
    plt.show()

# %%
class Generator(nn.Module):
    def __init__(self, latent_dim=100, ngf = 28, channels=1, bias = True):
        super().__init__()
        
        self.model = nn.Sequential(
            nn.ConvTranspose2d(latent_dim, ngf*4, kernel_size=4, stride=1, padding=0, bias=bias),
            nn.BatchNorm2d(ngf*4),
            nn.LeakyReLU(0.2, inplace=True),

            nn.ConvTranspose2d(ngf*4, ngf*2, kernel_size=4, stride=2, padding=1, bias=bias),
            nn.BatchNorm2d(ngf*2),
            nn.LeakyReLU(0.2, inplace=True),

            nn.ConvTranspose2d(ngf*2, ngf, kernel_size=4, stride=2, padding=1, bias=bias),
            nn.BatchNorm2d(ngf),
            nn.LeakyReLU(0.2, inplace=True),

            nn.ConvTranspose2d(ngf, channels, kernel_size=4, stride=2, padding=3, bias=bias),
            nn.Tanh()
        )

    def forward(self, z):
        return self.model(z)

# %%
class Discriminator(nn.Module):
    def __init__(self, ndf=28, channels=1, bias=True):
        super().__init__()
        
        def discriminator_block(in_features, out_features, bn=True):
            if bn:
                block = [
                         nn.Conv2d(in_features, out_features, 4, 2, 1, bias=bias),
                         nn.BatchNorm2d(out_features),
                         nn.LeakyReLU(0.2, inplace=True)
                ]
            else:
                block = [
                         nn.Conv2d(in_features, out_features, 4, 2, 3, bias=bias),
                         nn.LeakyReLU(0.2, inplace=True)
                ]
            return block

        self.features = nn.Sequential(
            *discriminator_block(channels, ndf, bn=False),
            *discriminator_block(ndf, ndf*2, bn=True),
            *discriminator_block(ndf*2, ndf*4, bn=True)
        )

        self.last_layer = nn.Sequential(
            nn.Conv2d(ndf*4, 1, 4, 1, 0, bias=bias),
            nn.Sigmoid()
        )

    def forward_features(self, x):
        features = self.features(x)
        return features

    def forward(self, x):
        features = self.forward_features(x)
        validity = self.last_layer(features)
        return validity

# %%
class Encoder(nn.Module):
    def __init__(self, latent_dim=100, ndf=28, channels=1, bias=True):
        super().__init__()
        
        def encoder_block(in_features, out_features, bn=True):
            if bn:
                block = [
                         nn.Conv2d(in_features, out_features, 4, 2, 1, bias=bias),
                         nn.BatchNorm2d(out_features),
                         nn.LeakyReLU(0.2, inplace=True)
                ]
            else:
                block = [
                         nn.Conv2d(in_features, out_features, 4, 2, 3, bias=bias),
                         nn.LeakyReLU(0.2, inplace=True)
                ]
            return block

        self.features = nn.Sequential(
            *encoder_block(channels, ndf, bn=False),
            *encoder_block(ndf, ndf*2, bn=True),
            *encoder_block(ndf*2, ndf*4, bn=True),
            nn.Conv2d(ndf*4, latent_dim, 4, 1, 0, bias=bias),
            nn.Tanh()
        )

    def forward(self, x):
        validity = self.features(x)
        return validity

# %%
n_epochs = 10
batch_size = 512
lr = 0.0002
ndf = 28
ngf = 28
latent_dim = 100
img_size = 28
channels = 1
n_critic = 5
sample_interval = 400
training_label = 0
split_rate = 0.8
lambda_gp = 10

# %%
class SimpleDataset(Dataset):
    def __init__(self, data, labels, transform=None):
        self.transform = transform
        self.data = data
        self.labels = labels

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        data = self.data[idx]
        labels = self.labels[idx]

        if self.transform:
            data = self.transform(data)

        return data, labels

# %%
import pandas as pd

df = pd.read_csv('./data/train.csv')
val_df = pd.read_csv('./data/val.csv')
test_df = pd.read_csv('./data/test.csv')

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

scaler = StandardScaler()
scaler.fit(df)

# %%
from sklearn.covariance import EllipticEnvelope

val_normal, val_fraud = val_df['Class'].value_counts()
val_contamination = val_fraud / val_normal

cov = EllipticEnvelope(support_fraction = 0.001, contamination = val_contamination+0.0002,random_state=777)
ee_pred = cov.fit_predict(df.drop('ID',axis=1))
ee_pred = list(map(lambda x : int(0) if x==1 else int(1), ee_pred))

df['targets'] = ee_pred
# Out:
# c:\Users\kimji\.conda\envs\for_pytorch\lib\site-packages\sklearn\covariance\_empirical_covariance.py:87: UserWarning: Only one sample available. You may want to reshape your data array
#   "Only one sample available. You may want to reshape your data array"

# %%
df.drop(['V8','V22'],axis=1,inplace=True)

# %%
ls2 = []
col = df.columns[1:-1]

for i in df[df['targets']==0].apply(lambda x : [x[i] for i in col],axis=1):
    ls = []
    for j in i:
        ls.append(np.array(i)*j)
    ls2.append(ls)

# %%
_x_train = torch.FloatTensor(ls2)
x_train, x_test_normal = _x_train.split((int(len(_x_train) * split_rate)), dim=0)

_y_train = torch.FloatTensor(df[df['targets']==0]['targets'])
y_train, y_test_normal = _y_train.split((int(len(_y_train) * split_rate)), dim=0)

train_mnist = SimpleDataset(x_train, y_train,
                                transform=transforms.Compose(
                                    [transforms.ToPILImage(),
                                     transforms.ToTensor(),
                                     transforms.Normalize([0.5], [0.5])])
                                )
train_dataloader = DataLoader(train_mnist, batch_size=batch_size, shuffle=True)

# %%
G = Generator(latent_dim = latent_dim, ngf=ngf, channels=channels, bias=True).to(device)
D = Discriminator(ndf=ndf, channels=channels, bias=True).to(device)

optimizer_G = optim.Adam(G.parameters(), lr=lr, weight_decay=1e-5)
optimizer_D = optim.Adam(D.parameters(), lr=lr, weight_decay=1e-5)

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs --port=6008

# %%
padding_epoch = len(str(n_epochs)) #3
padding_i = len(str(len(train_dataloader))) # 2

d_losses = []
g_losses = []

criterion = nn.BCELoss()

for epoch in range(n_epochs):
    for i, (imgs, _) in enumerate(train_dataloader):
        real_imgs = imgs.to(device)

        # ---------------------
        #  Train Discriminator
        # ---------------------
        optimizer_D.zero_grad()
        z = torch.randn(batch_size, latent_dim, 1, 1).to(device)

        fake_imgs = G(z)

        real_validity = D(real_imgs)
        fake_validity = D(fake_imgs.detach())
        
        # Adversarial loss
        d_loss_real = criterion(real_validity, torch.ones_like(real_validity).to(device))
        d_loss_fake = criterion(fake_validity, torch.zeros_like(fake_validity).to(device))
        d_loss = d_loss_real + d_loss_fake

        d_loss.backward()
        
        optimizer_D.step()
        
        if i % n_critic == 0:
            # -----------------
            #  Train Generator
            # -----------------
            optimizer_G.zero_grad()
            
            fake_imgs = G(z)
            fake_validity = D(fake_imgs)

            g_loss = criterion(fake_validity, torch.ones_like(fake_validity).to(device))

            g_loss.backward()
            optimizer_G.step()
            
            d_losses.append(d_loss)
            g_losses.append(g_loss)

            writer.add_scalars('GAN loss', {'G_loss': g_loss.item(), 'D_loss': d_loss.item()}, epoch)
            
            print(f"[Epoch {epoch:{padding_epoch}}/{n_epochs}] "
                f"[Batch {i:{padding_i}}/{len(train_dataloader)}] "
                f"[D loss: {d_loss.item():3f}] "
                f"[G loss: {g_loss.item():3f}]")
print('Finished Training')
# Out:
# [Epoch  0/10] [Batch   0/178] [D loss: 1.396476] [G loss: 0.847550]
# [Epoch  0/10] [Batch   5/178] [D loss: 0.814638] [G loss: 1.374948]
# [Epoch  0/10] [Batch  10/178] [D loss: 0.522458] [G loss: 1.748076]
# [Epoch  0/10] [Batch  15/178] [D loss: 0.381238] [G loss: 2.117270]
# [Epoch  0/10] [Batch  20/178] [D loss: 0.318181] [G loss: 2.441781]
# [Epoch  0/10] [Batch  25/178] [D loss: 0.262008] [G loss: 2.830462]
# [Epoch  0/10] [Batch  30/178] [D loss: 0.238787] [G loss: 3.085837]
# [Epoch  0/10] [Batch  35/178] [D loss: 0.185414] [G loss: 3.411253]
# [Epoch  0/10] [Batch  40/178] [D loss: 0.153989] [G loss: 3.752716]
# [Epoch  0/10] [Batch  45/178] [D loss: 0.129790] [G loss: 4.242389]
# [Epoch  0/10] [Batch  50/178] [D loss: 0.086564] [G loss: 4.584935]
# [Epoch  0/10] [Batch  55/178] [D loss: 0.064384] [G loss: 4.986243]
# [Epoch  0/10] [Batch  60/178] [D loss: 0.042562] [G loss: 5.248400]
# [Epoch  0/10] [Batch  65/178] [D loss: 0.034639] [G loss: 5.480873]
# [Epoch  0/10] [Batch  70/178] [D loss: 0.028447] [G loss: 5.759566]
# [Epoch  0/10] [Batch  75/178] [D loss: 0.030836] [G loss: 5.970512]
# [Epoch  0/10] [Batch  80/178] [D loss: 0.023314] [G loss: 6.217887]
# [Epoch  0/10] [Batch  85/178] [D loss: 0.032321] [G loss: 6.359585]
# [Epoch  0/10] [Batch  90/178] [D loss: 0.031882] [G loss: 6.730488]
# [Epoch  0/10] [Batch  95/178] [D loss: 0.034037] [G loss: 6.703238]
# [Epoch  0/10] [Batch 100/178] [D loss: 0.025832] [G loss: 6.872296]
# [Epoch  0/10] [Batch 105/178] [D loss: 0.021629] [G loss: 7.066740]
# [Epoch  0/10] [Batch 110/178] [D loss: 0.017512] [G loss: 7.188372]
# [Epoch  0/10] [Batch 115/178] [D loss: 0.012571] [G loss: 7.293756]
# [Epoch  0/10] [Batch 120/178] [D loss: 0.014004] [G loss: 7.321517]
# [Epoch  0/10] [Batch 125/178] [D loss: 0.016016] [G loss: 7.525741]
# [Epoch  0/10] [Batch 130/178] [D loss: 0.012891] [G loss: 7.549317]
# [Epoch  0/10] [Batch 135/178] [D loss: 0.017814] [G loss: 7.570768]
# [Epoch  0/10] [Batch 140/178] [D loss: 0.010254] [G loss: 7.566911]
# [Epoch  0/10] [Batch 145/178] [D loss: 0.009839] [G loss: 7.497400]
# [Epoch  0/10] [Batch 150/178] [D loss: 0.008295] [G loss: 7.748477]
# [Epoch  0/10] [Batch 155/178] [D loss: 0.010507] [G loss: 8.055748]
# [Epoch  0/10] [Batch 160/178] [D loss: 0.010001] [G loss: 8.052945]
# [Epoch  0/10] [Batch 165/178] [D loss: 0.008990] [G loss: 8.336992]
# [Epoch  0/10] [Batch 170/178] [D loss: 0.012917] [G loss: 8.453316]
# [Epoch  0/10] [Batch 175/178] [D loss: 0.009788] [G loss: 8.582203]
# [Epoch  1/10] [Batch   0/178] [D loss: 0.013002] [G loss: 7.631790]
# [Epoch  1/10] [Batch   5/178] [D loss: 0.014324] [G loss: 9.722612]
# [Epoch  1/10] [Batch  10/178] [D loss: 0.010335] [G loss: 9.802330]
# [Epoch  1/10] [Batch  15/178] [D loss: 0.005233] [G loss: 8.904703]
# [Epoch  1/10] [Batch  20/178] [D loss: 0.004375] [G loss: 7.658401]
# [Epoch  1/10] [Batch  25/178] [D loss: 0.004271] [G loss: 8.714846]
# [Epoch  1/10] [Batch  30/178] [D loss: 0.004579] [G loss: 9.177975]
# [Epoch  1/10] [Batch  35/178] [D loss: 0.004930] [G loss: 8.864623]
# [Epoch  1/10] [Batch  40/178] [D loss: 0.003891] [G loss: 8.242044]
# [Epoch  1/10] [Batch  45/178] [D loss: 0.003809] [G loss: 8.194594]
# [Epoch  1/10] [Batch  50/178] [D loss: 0.002861] [G loss: 8.635961]
# [Epoch  1/10] [Batch  55/178] [D loss: 0.003896] [G loss: 8.943386]
# [Epoch  1/10] [Batch  60/178] [D loss: 0.006288] [G loss: 8.701849]
# [Epoch  1/10] [Batch  65/178] [D loss: 0.003910] [G loss: 8.522465]
# [Epoch  1/10] [Batch  70/178] [D loss: 0.004261] [G loss: 8.754541]
# [Epoch  1/10] [Batch  75/178] [D loss: 0.002699] [G loss: 8.864801]
# [Epoch  1/10] [Batch  80/178] [D loss: 0.003128] [G loss: 8.756254]
# [Epoch  1/10] [Batch  85/178] [D loss: 0.002616] [G loss: 8.641853]
# [Epoch  1/10] [Batch  90/178] [D loss: 0.002161] [G loss: 8.771362]
# [Epoch  1/10] [Batch  95/178] [D loss: 0.003205] [G loss: 9.004534]
# [Epoch  1/10] [Batch 100/178] [D loss: 0.001615] [G loss: 9.013946]
# [Epoch  1/10] [Batch 105/178] [D loss: 0.003150] [G loss: 8.924541]
# [Epoch  1/10] [Batch 110/178] [D loss: 0.003342] [G loss: 9.063938]
# [Epoch  1/10] [Batch 115/178] [D loss: 0.002725] [G loss: 9.217133]
# [Epoch  1/10] [Batch 120/178] [D loss: 0.003560] [G loss: 9.215614]
# [Epoch  1/10] [Batch 125/178] [D loss: 0.001866] [G loss: 9.124521]
# [Epoch  1/10] [Batch 130/178] [D loss: 0.002853] [G loss: 9.144313]
# [Epoch  1/10] [Batch 135/178] [D loss: 0.002565] [G loss: 9.160846]
# [Epoch  1/10] [Batch 140/178] [D loss: 0.003716] [G loss: 9.385350]
# [Epoch  1/10] [Batch 145/178] [D loss: 0.002254] [G loss: 9.607773]
# [Epoch  1/10] [Batch 150/178] [D loss: 0.002270] [G loss: 9.656897]
# [Epoch  1/10] [Batch 155/178] [D loss: 0.002661] [G loss: 9.799204]
# [Epoch  1/10] [Batch 160/178] [D loss: 0.002444] [G loss: 10.044105]
# [Epoch  1/10] [Batch 165/178] [D loss: 0.002922] [G loss: 9.800422]
# [Epoch  1/10] [Batch 170/178] [D loss: 0.002675] [G loss: 9.377815]
# [Epoch  1/10] [Batch 175/178] [D loss: 0.002146] [G loss: 9.731519]
# [Epoch  2/10] [Batch   0/178] [D loss: 0.002241] [G loss: 9.027699]
# [Epoch  2/10] [Batch   5/178] [D loss: 0.002574] [G loss: 10.234556]
# [Epoch  2/10] [Batch  10/178] [D loss: 0.002285] [G loss: 10.388913]
# [Epoch  2/10] [Batch  15/178] [D loss: 0.001471] [G loss: 9.878149]
# [Epoch  2/10] [Batch  20/178] [D loss: 0.001788] [G loss: 9.190346]
# [Epoch  2/10] [Batch  25/178] [D loss: 0.002813] [G loss: 8.853311]
# [Epoch  2/10] [Batch  30/178] [D loss: 0.001551] [G loss: 9.271603]
# [Epoch  2/10] [Batch  35/178] [D loss: 0.001135] [G loss: 9.522850]
# [Epoch  2/10] [Batch  40/178] [D loss: 0.001318] [G loss: 9.729780]
# [Epoch  2/10] [Batch  45/178] [D loss: 0.001235] [G loss: 9.689516]
# [Epoch  2/10] [Batch  50/178] [D loss: 0.001584] [G loss: 9.740990]
# [Epoch  2/10] [Batch  55/178] [D loss: 0.001900] [G loss: 9.816168]
# [Epoch  2/10] [Batch  60/178] [D loss: 0.001144] [G loss: 10.117817]
# [Epoch  2/10] [Batch  65/178] [D loss: 0.002188] [G loss: 10.084229]
# [Epoch  2/10] [Batch  70/178] [D loss: 0.001811] [G loss: 10.139248]
# [Epoch  2/10] [Batch  75/178] [D loss: 0.001757] [G loss: 10.174273]
# [Epoch  2/10] [Batch  80/178] [D loss: 0.003878] [G loss: 10.153898]
# [Epoch  2/10] [Batch  85/178] [D loss: 0.001831] [G loss: 10.108921]
# [Epoch  2/10] [Batch  90/178] [D loss: 0.002049] [G loss: 10.031094]
# [Epoch  2/10] [Batch  95/178] [D loss: 0.002261] [G loss: 9.930317]
# [Epoch  2/10] [Batch 100/178] [D loss: 0.001884] [G loss: 10.042240]
# [Epoch  2/10] [Batch 105/178] [D loss: 0.001729] [G loss: 9.887749]
# [Epoch  2/10] [Batch 110/178] [D loss: 0.001805] [G loss: 9.899485]
# [Epoch  2/10] [Batch 115/178] [D loss: 0.002099] [G loss: 9.907181]
# [Epoch  2/10] [Batch 120/178] [D loss: 0.001612] [G loss: 9.927238]
# [Epoch  2/10] [Batch 125/178] [D loss: 0.001532] [G loss: 10.150949]
# [Epoch  2/10] [Batch 130/178] [D loss: 0.001517] [G loss: 10.035165]
# [Epoch  2/10] [Batch 135/178] [D loss: 0.001811] [G loss: 9.867844]
# [Epoch  2/10] [Batch 140/178] [D loss: 0.002637] [G loss: 10.330629]
# [Epoch  2/10] [Batch 145/178] [D loss: 0.002674] [G loss: 10.147552]
# [Epoch  2/10] [Batch 150/178] [D loss: 0.001711] [G loss: 9.791651]
# [Epoch  2/10] [Batch 155/178] [D loss: 0.003037] [G loss: 9.647152]
# [Epoch  2/10] [Batch 160/178] [D loss: 0.001891] [G loss: 10.705914]
# [Epoch  2/10] [Batch 165/178] [D loss: 0.001702] [G loss: 10.820493]
# [Epoch  2/10] [Batch 170/178] [D loss: 0.001586] [G loss: 10.348295]
# [Epoch  2/10] [Batch 175/178] [D loss: 0.002297] [G loss: 9.575550]
# [Epoch  3/10] [Batch   0/178] [D loss: 0.003479] [G loss: 8.694937]
# [Epoch  3/10] [Batch   5/178] [D loss: 0.001611] [G loss: 10.512394]
# [Epoch  3/10] [Batch  10/178] [D loss: 0.002137] [G loss: 11.046038]
# [Epoch  3/10] [Batch  15/178] [D loss: 0.001356] [G loss: 10.712872]
# [Epoch  3/10] [Batch  20/178] [D loss: 0.001166] [G loss: 9.742042]
# [Epoch  3/10] [Batch  25/178] [D loss: 0.001275] [G loss: 9.182034]
# [Epoch  3/10] [Batch  30/178] [D loss: 0.001131] [G loss: 9.468367]
# [Epoch  3/10] [Batch  35/178] [D loss: 0.001115] [G loss: 9.362102]
# [Epoch  3/10] [Batch  40/178] [D loss: 0.001914] [G loss: 9.313703]
# [Epoch  3/10] [Batch  45/178] [D loss: 0.001259] [G loss: 8.964077]
# [Epoch  3/10] [Batch  50/178] [D loss: 0.001131] [G loss: 8.820560]
# [Epoch  3/10] [Batch  55/178] [D loss: 0.001861] [G loss: 8.851473]
# [Epoch  3/10] [Batch  60/178] [D loss: 0.001294] [G loss: 9.067432]
# [Epoch  3/10] [Batch  65/178] [D loss: 0.000989] [G loss: 9.271136]
# [Epoch  3/10] [Batch  70/178] [D loss: 0.001262] [G loss: 9.113110]
# [Epoch  3/10] [Batch  75/178] [D loss: 0.000993] [G loss: 9.280214]
# [Epoch  3/10] [Batch  80/178] [D loss: 0.001177] [G loss: 9.280014]
# [Epoch  3/10] [Batch  85/178] [D loss: 0.001493] [G loss: 9.219173]
# [Epoch  3/10] [Batch  90/178] [D loss: 0.001092] [G loss: 9.477532]
# [Epoch  3/10] [Batch  95/178] [D loss: 0.000868] [G loss: 9.494783]
# [Epoch  3/10] [Batch 100/178] [D loss: 0.001381] [G loss: 9.000298]
# [Epoch  3/10] [Batch 105/178] [D loss: 0.001130] [G loss: 9.075819]
# [Epoch  3/10] [Batch 110/178] [D loss: 0.000950] [G loss: 9.207205]
# [Epoch  3/10] [Batch 115/178] [D loss: 0.001289] [G loss: 9.525389]
# [Epoch  3/10] [Batch 120/178] [D loss: 0.000867] [G loss: 9.553422]
# [Epoch  3/10] [Batch 125/178] [D loss: 0.000983] [G loss: 9.269466]
# [Epoch  3/10] [Batch 130/178] [D loss: 0.000844] [G loss: 9.155095]
# [Epoch  3/10] [Batch 135/178] [D loss: 0.000975] [G loss: 9.056125]
# [Epoch  3/10] [Batch 140/178] [D loss: 0.001010] [G loss: 9.166332]
# [Epoch  3/10] [Batch 145/178] [D loss: 0.001261] [G loss: 9.350280]
# [Epoch  3/10] [Batch 150/178] [D loss: 0.001182] [G loss: 9.357002]
# [Epoch  3/10] [Batch 155/178] [D loss: 0.001063] [G loss: 9.168571]
# [Epoch  3/10] [Batch 160/178] [D loss: 0.001235] [G loss: 9.297054]
# [Epoch  3/10] [Batch 165/178] [D loss: 0.001193] [G loss: 9.399638]
# [Epoch  3/10] [Batch 170/178] [D loss: 0.000943] [G loss: 9.606230]
# [Epoch  3/10] [Batch 175/178] [D loss: 0.001216] [G loss: 9.524458]
# [Epoch  4/10] [Batch   0/178] [D loss: 0.001439] [G loss: 8.684847]
# [Epoch  4/10] [Batch   5/178] [D loss: 0.001321] [G loss: 10.607234]
# [Epoch  4/10] [Batch  10/178] [D loss: 0.001663] [G loss: 10.932094]
# [Epoch  4/10] [Batch  15/178] [D loss: 0.001097] [G loss: 10.397987]
# [Epoch  4/10] [Batch  20/178] [D loss: 0.000836] [G loss: 9.375956]
# [Epoch  4/10] [Batch  25/178] [D loss: 0.001532] [G loss: 8.784323]
# [Epoch  4/10] [Batch  30/178] [D loss: 0.001340] [G loss: 8.997019]
# [Epoch  4/10] [Batch  35/178] [D loss: 0.000917] [G loss: 9.504184]
# [Epoch  4/10] [Batch  40/178] [D loss: 0.001308] [G loss: 9.148036]
# [Epoch  4/10] [Batch  45/178] [D loss: 0.001233] [G loss: 9.211193]
# [Epoch  4/10] [Batch  50/178] [D loss: 0.001134] [G loss: 8.985767]
# [Epoch  4/10] [Batch  55/178] [D loss: 0.000993] [G loss: 9.099201]
# [Epoch  4/10] [Batch  60/178] [D loss: 0.001291] [G loss: 9.064754]
# [Epoch  4/10] [Batch  65/178] [D loss: 0.001463] [G loss: 9.210039]
# [Epoch  4/10] [Batch  70/178] [D loss: 0.001483] [G loss: 8.739521]
# [Epoch  4/10] [Batch  75/178] [D loss: 0.001376] [G loss: 8.839802]
# [Epoch  4/10] [Batch  80/178] [D loss: 0.000977] [G loss: 8.879965]
# [Epoch  4/10] [Batch  85/178] [D loss: 0.000991] [G loss: 8.956835]
# [Epoch  4/10] [Batch  90/178] [D loss: 0.001877] [G loss: 8.703969]
# [Epoch  4/10] [Batch  95/178] [D loss: 0.001481] [G loss: 8.886595]
# [Epoch  4/10] [Batch 100/178] [D loss: 0.001153] [G loss: 8.902096]
# [Epoch  4/10] [Batch 105/178] [D loss: 0.001770] [G loss: 8.834311]
# [Epoch  4/10] [Batch 110/178] [D loss: 0.001210] [G loss: 8.779826]
# [Epoch  4/10] [Batch 115/178] [D loss: 0.001215] [G loss: 8.960238]
# [Epoch  4/10] [Batch 120/178] [D loss: 0.001323] [G loss: 8.939728]
# [Epoch  4/10] [Batch 125/178] [D loss: 0.001444] [G loss: 8.511791]
# [Epoch  4/10] [Batch 130/178] [D loss: 0.001131] [G loss: 8.882368]
# [Epoch  4/10] [Batch 135/178] [D loss: 0.001329] [G loss: 8.873816]
# [Epoch  4/10] [Batch 140/178] [D loss: 0.001057] [G loss: 8.903276]
# [Epoch  4/10] [Batch 145/178] [D loss: 0.000788] [G loss: 8.981496]
# [Epoch  4/10] [Batch 150/178] [D loss: 0.000967] [G loss: 9.017037]
# [Epoch  4/10] [Batch 155/178] [D loss: 0.001088] [G loss: 9.166035]
# [Epoch  4/10] [Batch 160/178] [D loss: 0.000737] [G loss: 9.404712]
# [Epoch  4/10] [Batch 165/178] [D loss: 0.000946] [G loss: 9.356047]
# [Epoch  4/10] [Batch 170/178] [D loss: 0.000875] [G loss: 9.517151]
# [Epoch  4/10] [Batch 175/178] [D loss: 0.001232] [G loss: 9.236250]
# [Epoch  5/10] [Batch   0/178] [D loss: 0.001100] [G loss: 8.804466]
# [Epoch  5/10] [Batch   5/178] [D loss: 0.000793] [G loss: 10.021488]
# [Epoch  5/10] [Batch  10/178] [D loss: 0.000949] [G loss: 10.283056]
# [Epoch  5/10] [Batch  15/178] [D loss: 0.000950] [G loss: 10.012396]
# [Epoch  5/10] [Batch  20/178] [D loss: 0.000848] [G loss: 9.524782]
# [Epoch  5/10] [Batch  25/178] [D loss: 0.000706] [G loss: 10.113307]
# [Epoch  5/10] [Batch  30/178] [D loss: 0.001054] [G loss: 10.225035]
# [Epoch  5/10] [Batch  35/178] [D loss: 0.001175] [G loss: 10.111877]
# [Epoch  5/10] [Batch  40/178] [D loss: 0.001336] [G loss: 10.212565]
# [Epoch  5/10] [Batch  45/178] [D loss: 0.001299] [G loss: 10.275679]
# [Epoch  5/10] [Batch  50/178] [D loss: 0.000883] [G loss: 10.495082]
# [Epoch  5/10] [Batch  55/178] [D loss: 0.000828] [G loss: 10.594275]
# [Epoch  5/10] [Batch  60/178] [D loss: 0.001228] [G loss: 10.249956]
# [Epoch  5/10] [Batch  65/178] [D loss: 0.000945] [G loss: 9.924610]
# [Epoch  5/10] [Batch  70/178] [D loss: 0.000608] [G loss: 9.864979]
# [Epoch  5/10] [Batch  75/178] [D loss: 0.001125] [G loss: 9.485331]
# [Epoch  5/10] [Batch  80/178] [D loss: 0.000885] [G loss: 9.324100]
# [Epoch  5/10] [Batch  85/178] [D loss: 0.000823] [G loss: 9.561119]
# [Epoch  5/10] [Batch  90/178] [D loss: 0.001083] [G loss: 9.194970]
# [Epoch  5/10] [Batch  95/178] [D loss: 0.001114] [G loss: 8.967103]
# [Epoch  5/10] [Batch 100/178] [D loss: 0.001123] [G loss: 8.907158]
# [Epoch  5/10] [Batch 105/178] [D loss: 0.001134] [G loss: 9.305624]
# [Epoch  5/10] [Batch 110/178] [D loss: 0.001245] [G loss: 9.171869]
# [Epoch  5/10] [Batch 115/178] [D loss: 0.001376] [G loss: 9.117805]
# [Epoch  5/10] [Batch 120/178] [D loss: 0.001627] [G loss: 9.126614]
# [Epoch  5/10] [Batch 125/178] [D loss: 0.001219] [G loss: 9.430624]
# [Epoch  5/10] [Batch 130/178] [D loss: 0.001066] [G loss: 9.791359]
# [Epoch  5/10] [Batch 135/178] [D loss: 0.001115] [G loss: 9.425701]
# [Epoch  5/10] [Batch 140/178] [D loss: 0.001390] [G loss: 9.368871]
# [Epoch  5/10] [Batch 145/178] [D loss: 0.001058] [G loss: 9.286956]
# [Epoch  5/10] [Batch 150/178] [D loss: 0.001136] [G loss: 9.298395]
# [Epoch  5/10] [Batch 155/178] [D loss: 0.001216] [G loss: 9.231913]
# [Epoch  5/10] [Batch 160/178] [D loss: 0.000989] [G loss: 9.448849]
# [Epoch  5/10] [Batch 165/178] [D loss: 0.000956] [G loss: 9.206100]
# [Epoch  5/10] [Batch 170/178] [D loss: 0.000852] [G loss: 9.416762]
# [Epoch  5/10] [Batch 175/178] [D loss: 0.000920] [G loss: 9.407717]
# [Epoch  6/10] [Batch   0/178] [D loss: 0.001172] [G loss: 8.914192]
# [Epoch  6/10] [Batch   5/178] [D loss: 0.001205] [G loss: 9.452990]
# [Epoch  6/10] [Batch  10/178] [D loss: 0.000787] [G loss: 9.495739]
# [Epoch  6/10] [Batch  15/178] [D loss: 0.000776] [G loss: 9.341848]
# [Epoch  6/10] [Batch  20/178] [D loss: 0.000742] [G loss: 9.247720]
# [Epoch  6/10] [Batch  25/178] [D loss: 0.000955] [G loss: 9.110678]
# [Epoch  6/10] [Batch  30/178] [D loss: 0.001031] [G loss: 9.241041]
# [Epoch  6/10] [Batch  35/178] [D loss: 0.000692] [G loss: 9.402206]
# [Epoch  6/10] [Batch  40/178] [D loss: 0.000918] [G loss: 9.416355]
# [Epoch  6/10] [Batch  45/178] [D loss: 0.000734] [G loss: 9.363800]
# [Epoch  6/10] [Batch  50/178] [D loss: 0.000736] [G loss: 9.255724]
# [Epoch  6/10] [Batch  55/178] [D loss: 0.000741] [G loss: 9.408328]
# [Epoch  6/10] [Batch  60/178] [D loss: 0.000721] [G loss: 9.608675]
# [Epoch  6/10] [Batch  65/178] [D loss: 0.000649] [G loss: 9.568796]
# [Epoch  6/10] [Batch  70/178] [D loss: 0.000631] [G loss: 9.362779]
# [Epoch  6/10] [Batch  75/178] [D loss: 0.000692] [G loss: 9.614212]
# [Epoch  6/10] [Batch  80/178] [D loss: 0.000702] [G loss: 9.626911]
# [Epoch  6/10] [Batch  85/178] [D loss: 0.000663] [G loss: 9.563830]
# [Epoch  6/10] [Batch  90/178] [D loss: 0.000514] [G loss: 9.469294]
# [Epoch  6/10] [Batch  95/178] [D loss: 0.000471] [G loss: 9.650152]
# [Epoch  6/10] [Batch 100/178] [D loss: 0.000540] [G loss: 9.661894]
# [Epoch  6/10] [Batch 105/178] [D loss: 0.000576] [G loss: 9.860700]
# [Epoch  6/10] [Batch 110/178] [D loss: 0.000619] [G loss: 9.707005]
# [Epoch  6/10] [Batch 115/178] [D loss: 0.000595] [G loss: 9.424458]
# [Epoch  6/10] [Batch 120/178] [D loss: 0.000491] [G loss: 9.609152]
# [Epoch  6/10] [Batch 125/178] [D loss: 0.000605] [G loss: 9.715590]
# [Epoch  6/10] [Batch 130/178] [D loss: 0.000621] [G loss: 9.604137]
# [Epoch  6/10] [Batch 135/178] [D loss: 0.000654] [G loss: 9.494207]
# [Epoch  6/10] [Batch 140/178] [D loss: 0.000665] [G loss: 9.487284]
# [Epoch  6/10] [Batch 145/178] [D loss: 0.000527] [G loss: 9.612272]
# [Epoch  6/10] [Batch 150/178] [D loss: 0.000715] [G loss: 9.547054]
# [Epoch  6/10] [Batch 155/178] [D loss: 0.000386] [G loss: 9.630922]
# [Epoch  6/10] [Batch 160/178] [D loss: 0.000387] [G loss: 9.516675]
# [Epoch  6/10] [Batch 165/178] [D loss: 0.000457] [G loss: 9.618414]
# [Epoch  6/10] [Batch 170/178] [D loss: 0.000427] [G loss: 9.431968]
# [Epoch  6/10] [Batch 175/178] [D loss: 0.000519] [G loss: 9.389505]
# [Epoch  7/10] [Batch   0/178] [D loss: 0.000554] [G loss: 9.233379]
# [Epoch  7/10] [Batch   5/178] [D loss: 0.000532] [G loss: 9.265748]
# [Epoch  7/10] [Batch  10/178] [D loss: 0.000514] [G loss: 9.529823]
# [Epoch  7/10] [Batch  15/178] [D loss: 0.000521] [G loss: 9.567464]
# [Epoch  7/10] [Batch  20/178] [D loss: 0.000397] [G loss: 9.631249]
# [Epoch  7/10] [Batch  25/178] [D loss: 0.000492] [G loss: 9.568787]
# [Epoch  7/10] [Batch  30/178] [D loss: 0.000616] [G loss: 9.508202]
# [Epoch  7/10] [Batch  35/178] [D loss: 0.000487] [G loss: 9.465410]
# [Epoch  7/10] [Batch  40/178] [D loss: 0.000693] [G loss: 9.800628]
# [Epoch  7/10] [Batch  45/178] [D loss: 0.000863] [G loss: 9.881472]
# [Epoch  7/10] [Batch  50/178] [D loss: 0.000701] [G loss: 9.882965]
# [Epoch  7/10] [Batch  55/178] [D loss: 0.001227] [G loss: 10.053242]
# [Epoch  7/10] [Batch  60/178] [D loss: 0.001121] [G loss: 10.498459]
# [Epoch  7/10] [Batch  65/178] [D loss: 0.000849] [G loss: 10.283680]
# [Epoch  7/10] [Batch  70/178] [D loss: 0.000727] [G loss: 9.877539]
# [Epoch  7/10] [Batch  75/178] [D loss: 0.000978] [G loss: 10.880150]
# [Epoch  7/10] [Batch  80/178] [D loss: 0.001035] [G loss: 10.936933]
# [Epoch  7/10] [Batch  85/178] [D loss: 0.000813] [G loss: 9.880753]
# [Epoch  7/10] [Batch  90/178] [D loss: 0.000676] [G loss: 10.698204]
# [Epoch  7/10] [Batch  95/178] [D loss: 0.000923] [G loss: 10.790052]
# [Epoch  7/10] [Batch 100/178] [D loss: 0.000690] [G loss: 10.444569]
# [Epoch  7/10] [Batch 105/178] [D loss: 0.000797] [G loss: 10.591434]
# [Epoch  7/10] [Batch 110/178] [D loss: 0.000612] [G loss: 10.454370]
# [Epoch  7/10] [Batch 115/178] [D loss: 0.000509] [G loss: 10.777163]
# [Epoch  7/10] [Batch 120/178] [D loss: 0.000682] [G loss: 10.563475]
# [Epoch  7/10] [Batch 125/178] [D loss: 0.000624] [G loss: 10.344460]
# [Epoch  7/10] [Batch 130/178] [D loss: 0.000395] [G loss: 10.939307]
# [Epoch  7/10] [Batch 135/178] [D loss: 0.000883] [G loss: 10.624154]
# [Epoch  7/10] [Batch 140/178] [D loss: 0.000674] [G loss: 10.614861]
# [Epoch  7/10] [Batch 145/178] [D loss: 0.000668] [G loss: 10.634637]
# [Epoch  7/10] [Batch 150/178] [D loss: 0.000883] [G loss: 10.943729]
# [Epoch  7/10] [Batch 155/178] [D loss: 0.001142] [G loss: 10.961804]
# [Epoch  7/10] [Batch 160/178] [D loss: 0.001038] [G loss: 10.846563]
# [Epoch  7/10] [Batch 165/178] [D loss: 0.000597] [G loss: 10.800331]
# [Epoch  7/10] [Batch 170/178] [D loss: 0.000483] [G loss: 11.144994]
# [Epoch  7/10] [Batch 175/178] [D loss: 0.000434] [G loss: 10.765931]
# [Epoch  8/10] [Batch   0/178] [D loss: 0.000706] [G loss: 9.761461]
# [Epoch  8/10] [Batch   5/178] [D loss: 0.001426] [G loss: 12.829943]
# [Epoch  8/10] [Batch  10/178] [D loss: 0.000891] [G loss: 12.470219]
# [Epoch  8/10] [Batch  15/178] [D loss: 0.000301] [G loss: 10.887648]
# [Epoch  8/10] [Batch  20/178] [D loss: 0.000243] [G loss: 10.100809]
# [Epoch  8/10] [Batch  25/178] [D loss: 0.000229] [G loss: 10.618137]
# [Epoch  8/10] [Batch  30/178] [D loss: 0.000238] [G loss: 10.768380]
# [Epoch  8/10] [Batch  35/178] [D loss: 0.000290] [G loss: 10.597665]
# [Epoch  8/10] [Batch  40/178] [D loss: 0.000270] [G loss: 10.233449]
# [Epoch  8/10] [Batch  45/178] [D loss: 0.000277] [G loss: 10.080466]
# [Epoch  8/10] [Batch  50/178] [D loss: 0.000348] [G loss: 10.300885]
# [Epoch  8/10] [Batch  55/178] [D loss: 0.000343] [G loss: 10.288215]
# [Epoch  8/10] [Batch  60/178] [D loss: 0.000397] [G loss: 10.358581]
# [Epoch  8/10] [Batch  65/178] [D loss: 0.000551] [G loss: 10.292953]
# [Epoch  8/10] [Batch  70/178] [D loss: 0.000419] [G loss: 10.233099]
# [Epoch  8/10] [Batch  75/178] [D loss: 0.000336] [G loss: 10.136612]
# [Epoch  8/10] [Batch  80/178] [D loss: 0.000368] [G loss: 10.364653]
# [Epoch  8/10] [Batch  85/178] [D loss: 0.000390] [G loss: 10.335783]
# [Epoch  8/10] [Batch  90/178] [D loss: 0.000358] [G loss: 10.524862]
# [Epoch  8/10] [Batch  95/178] [D loss: 0.000387] [G loss: 10.353842]
# [Epoch  8/10] [Batch 100/178] [D loss: 0.000362] [G loss: 10.146533]
# [Epoch  8/10] [Batch 105/178] [D loss: 0.000433] [G loss: 10.181435]
# [Epoch  8/10] [Batch 110/178] [D loss: 0.000282] [G loss: 10.382820]
# [Epoch  8/10] [Batch 115/178] [D loss: 0.000419] [G loss: 10.633335]
# [Epoch  8/10] [Batch 120/178] [D loss: 0.000373] [G loss: 10.526463]
# [Epoch  8/10] [Batch 125/178] [D loss: 0.000395] [G loss: 10.279052]
# [Epoch  8/10] [Batch 130/178] [D loss: 0.000334] [G loss: 10.497018]
# [Epoch  8/10] [Batch 135/178] [D loss: 0.000308] [G loss: 10.406984]
# [Epoch  8/10] [Batch 140/178] [D loss: 0.000412] [G loss: 10.494670]
# [Epoch  8/10] [Batch 145/178] [D loss: 0.000326] [G loss: 10.661882]
# [Epoch  8/10] [Batch 150/178] [D loss: 0.000361] [G loss: 10.337048]
# [Epoch  8/10] [Batch 155/178] [D loss: 0.000301] [G loss: 10.413160]
# [Epoch  8/10] [Batch 160/178] [D loss: 0.000275] [G loss: 10.683401]
# [Epoch  8/10] [Batch 165/178] [D loss: 0.000469] [G loss: 10.352900]
# [Epoch  8/10] [Batch 170/178] [D loss: 0.000248] [G loss: 10.289761]
# [Epoch  8/10] [Batch 175/178] [D loss: 0.000205] [G loss: 10.910864]
# [Epoch  9/10] [Batch   0/178] [D loss: 0.000292] [G loss: 10.096230]
# [Epoch  9/10] [Batch   5/178] [D loss: 0.000297] [G loss: 10.695922]
# [Epoch  9/10] [Batch  10/178] [D loss: 0.000209] [G loss: 10.687816]
# [Epoch  9/10] [Batch  15/178] [D loss: 0.000193] [G loss: 10.634913]
# [Epoch  9/10] [Batch  20/178] [D loss: 0.000240] [G loss: 10.359794]
# [Epoch  9/10] [Batch  25/178] [D loss: 0.000275] [G loss: 10.402975]
# [Epoch  9/10] [Batch  30/178] [D loss: 0.000269] [G loss: 10.422625]
# [Epoch  9/10] [Batch  35/178] [D loss: 0.000156] [G loss: 10.624526]
# [Epoch  9/10] [Batch  40/178] [D loss: 0.000219] [G loss: 10.513602]
# [Epoch  9/10] [Batch  45/178] [D loss: 0.000177] [G loss: 10.503696]
# [Epoch  9/10] [Batch  50/178] [D loss: 0.000227] [G loss: 10.676586]
# [Epoch  9/10] [Batch  55/178] [D loss: 0.000203] [G loss: 10.557083]
# [Epoch  9/10] [Batch  60/178] [D loss: 0.000263] [G loss: 10.673294]
# [Epoch  9/10] [Batch  65/178] [D loss: 0.000211] [G loss: 10.622437]
# [Epoch  9/10] [Batch  70/178] [D loss: 0.000252] [G loss: 10.927467]
# [Epoch  9/10] [Batch  75/178] [D loss: 0.000293] [G loss: 10.670321]
# [Epoch  9/10] [Batch  80/178] [D loss: 0.000513] [G loss: 10.709280]
# [Epoch  9/10] [Batch  85/178] [D loss: 0.000283] [G loss: 10.555908]
# [Epoch  9/10] [Batch  90/178] [D loss: 0.000223] [G loss: 10.706250]
# [Epoch  9/10] [Batch  95/178] [D loss: 0.000320] [G loss: 10.762716]
# [Epoch  9/10] [Batch 100/178] [D loss: 0.000299] [G loss: 10.710485]
# [Epoch  9/10] [Batch 105/178] [D loss: 0.000462] [G loss: 10.613972]
# [Epoch  9/10] [Batch 110/178] [D loss: 0.000343] [G loss: 10.489985]
# [Epoch  9/10] [Batch 115/178] [D loss: 0.000376] [G loss: 10.523945]
# [Epoch  9/10] [Batch 120/178] [D loss: 0.000234] [G loss: 10.567768]
# [Epoch  9/10] [Batch 125/178] [D loss: 0.000318] [G loss: 10.572409]
# [Epoch  9/10] [Batch 130/178] [D loss: 0.000335] [G loss: 10.311780]
# [Epoch  9/10] [Batch 135/178] [D loss: 0.000396] [G loss: 10.585030]
# [Epoch  9/10] [Batch 140/178] [D loss: 0.000348] [G loss: 10.380499]
# [Epoch  9/10] [Batch 145/178] [D loss: 0.000290] [G loss: 10.569546]
# [Epoch  9/10] [Batch 150/178] [D loss: 0.000405] [G loss: 10.544636]
# [Epoch  9/10] [Batch 155/178] [D loss: 0.000414] [G loss: 10.508545]
# [Epoch  9/10] [Batch 160/178] [D loss: 0.000278] [G loss: 10.492277]
# [Epoch  9/10] [Batch 165/178] [D loss: 0.000379] [G loss: 10.312958]
# [Epoch  9/10] [Batch 170/178] [D loss: 0.000264] [G loss: 10.426952]
# [Epoch  9/10] [Batch 175/178] [D loss: 0.000242] [G loss: 10.351408]
# Finished Training

# %%
# plt.plot(g_losses, label='g_loss')
# plt.plot(d_losses, label='d_loss')
# plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# plt.show()

# %%
z = torch.randn(64, latent_dim, 1, 1).to(device)
imshow_grid(G(z))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (3, 242, 242)

# %%
fake_imgs[0].shape
# Out:
# torch.Size([1, 28, 28])

# %%
writer = SummaryWriter(logdir='runs/Encoder_training')

E = Encoder(latent_dim, ndf, channels, bias=True).to(device)

G.eval()
D.eval()

criterion = nn.MSELoss()

optimizer_E = torch.optim.Adam(E.parameters(), lr=lr, betas=(0.0, 0.999))

padding_epoch = len(str(n_epochs))
padding_i = len(str(len(train_dataloader)))
kappa = 1.0
e_losses = []

for epoch in range(n_epochs):
    for i, (imgs, _) in enumerate(train_dataloader):
        real_imgs = imgs.to(device)
        
        optimizer_E.zero_grad() 
        z = E(real_imgs)
        
        fake_imgs = G(z)

        real_features = D.forward_features(real_imgs)
        fake_features = D.forward_features(fake_imgs)
        # real_feature = real_features / real_features.max()
        # fake_features = fake_features / fake_features.max()

        # izif architecture
        loss_imgs = criterion(fake_imgs, real_imgs)
        loss_features = criterion(fake_features, real_features)
        e_loss = loss_imgs + kappa * loss_features

        e_loss.backward()
        optimizer_E.step()


        if i % n_critic == 0:
            e_losses.append(e_loss)

            writer.add_scalar('e_loss', e_loss.item(), epoch)
            print(f"[Epoch {epoch:{padding_epoch}}/{n_epochs}] "
                    f"[Batch {i:{padding_i}}/{len(train_dataloader)}] "
                    f"[E loss: {e_loss.item():3f}]")
            
#writer.close()
print('Finished Training')
# Out:
# [Epoch  0/10] [Batch   0/178] [E loss: 1.940773]
# [Epoch  0/10] [Batch   5/178] [E loss: 1.676309]
# [Epoch  0/10] [Batch  10/178] [E loss: 1.656092]
# [Epoch  0/10] [Batch  15/178] [E loss: 1.637120]
# [Epoch  0/10] [Batch  20/178] [E loss: 1.614772]
# [Epoch  0/10] [Batch  25/178] [E loss: 1.596959]
# [Epoch  0/10] [Batch  30/178] [E loss: 1.590282]
# [Epoch  0/10] [Batch  35/178] [E loss: 1.563783]
# [Epoch  0/10] [Batch  40/178] [E loss: 1.553007]
# [Epoch  0/10] [Batch  45/178] [E loss: 1.539671]
# [Epoch  0/10] [Batch  50/178] [E loss: 1.564884]
# [Epoch  0/10] [Batch  55/178] [E loss: 1.547019]
# [Epoch  0/10] [Batch  60/178] [E loss: 1.532475]
# [Epoch  0/10] [Batch  65/178] [E loss: 1.556830]
# [Epoch  0/10] [Batch  70/178] [E loss: 1.547458]
# [Epoch  0/10] [Batch  75/178] [E loss: 1.534915]
# [Epoch  0/10] [Batch  80/178] [E loss: 1.553013]
# [Epoch  0/10] [Batch  85/178] [E loss: 1.512909]
# [Epoch  0/10] [Batch  90/178] [E loss: 1.542485]
# [Epoch  0/10] [Batch  95/178] [E loss: 1.528123]
# [Epoch  0/10] [Batch 100/178] [E loss: 1.503510]
# [Epoch  0/10] [Batch 105/178] [E loss: 1.541468]
# [Epoch  0/10] [Batch 110/178] [E loss: 1.518278]
# [Epoch  0/10] [Batch 115/178] [E loss: 1.527921]
# [Epoch  0/10] [Batch 120/178] [E loss: 1.537456]
# [Epoch  0/10] [Batch 125/178] [E loss: 1.514227]
# [Epoch  0/10] [Batch 130/178] [E loss: 1.509152]
# [Epoch  0/10] [Batch 135/178] [E loss: 1.514329]
# [Epoch  0/10] [Batch 140/178] [E loss: 1.501278]
# [Epoch  0/10] [Batch 145/178] [E loss: 1.517250]
# [Epoch  0/10] [Batch 150/178] [E loss: 1.529040]
# [Epoch  0/10] [Batch 155/178] [E loss: 1.505420]
# [Epoch  0/10] [Batch 160/178] [E loss: 1.501259]
# [Epoch  0/10] [Batch 165/178] [E loss: 1.497559]
# [Epoch  0/10] [Batch 170/178] [E loss: 1.526783]
# [Epoch  0/10] [Batch 175/178] [E loss: 1.497642]
# [Epoch  1/10] [Batch   0/178] [E loss: 1.485967]
# [Epoch  1/10] [Batch   5/178] [E loss: 1.491451]
# [Epoch  1/10] [Batch  10/178] [E loss: 1.511398]
# [Epoch  1/10] [Batch  15/178] [E loss: 1.503204]
# [Epoch  1/10] [Batch  20/178] [E loss: 1.528051]
# [Epoch  1/10] [Batch  25/178] [E loss: 1.521429]
# [Epoch  1/10] [Batch  30/178] [E loss: 1.509787]
# [Epoch  1/10] [Batch  35/178] [E loss: 1.510140]
# [Epoch  1/10] [Batch  40/178] [E loss: 1.505975]
# [Epoch  1/10] [Batch  45/178] [E loss: 1.506905]
# [Epoch  1/10] [Batch  50/178] [E loss: 1.491159]
# [Epoch  1/10] [Batch  55/178] [E loss: 1.516471]
# [Epoch  1/10] [Batch  60/178] [E loss: 1.490888]
# [Epoch  1/10] [Batch  65/178] [E loss: 1.489495]
# [Epoch  1/10] [Batch  70/178] [E loss: 1.502172]
# [Epoch  1/10] [Batch  75/178] [E loss: 1.504149]
# [Epoch  1/10] [Batch  80/178] [E loss: 1.479191]
# [Epoch  1/10] [Batch  85/178] [E loss: 1.487443]
# [Epoch  1/10] [Batch  90/178] [E loss: 1.490005]
# [Epoch  1/10] [Batch  95/178] [E loss: 1.501852]
# [Epoch  1/10] [Batch 100/178] [E loss: 1.496808]
# [Epoch  1/10] [Batch 105/178] [E loss: 1.495944]
# [Epoch  1/10] [Batch 110/178] [E loss: 1.486966]
# [Epoch  1/10] [Batch 115/178] [E loss: 1.482853]
# [Epoch  1/10] [Batch 120/178] [E loss: 1.476321]
# [Epoch  1/10] [Batch 125/178] [E loss: 1.486253]
# [Epoch  1/10] [Batch 130/178] [E loss: 1.485725]
# [Epoch  1/10] [Batch 135/178] [E loss: 1.497175]
# [Epoch  1/10] [Batch 140/178] [E loss: 1.489291]
# [Epoch  1/10] [Batch 145/178] [E loss: 1.485705]
# [Epoch  1/10] [Batch 150/178] [E loss: 1.491240]
# [Epoch  1/10] [Batch 155/178] [E loss: 1.490755]
# [Epoch  1/10] [Batch 160/178] [E loss: 1.495400]
# [Epoch  1/10] [Batch 165/178] [E loss: 1.475707]
# [Epoch  1/10] [Batch 170/178] [E loss: 1.488314]
# [Epoch  1/10] [Batch 175/178] [E loss: 1.476137]
# [Epoch  2/10] [Batch   0/178] [E loss: 1.490531]
# [Epoch  2/10] [Batch   5/178] [E loss: 1.490530]
# [Epoch  2/10] [Batch  10/178] [E loss: 1.507594]
# [Epoch  2/10] [Batch  15/178] [E loss: 1.493212]
# [Epoch  2/10] [Batch  20/178] [E loss: 1.484111]
# [Epoch  2/10] [Batch  25/178] [E loss: 1.483333]
# [Epoch  2/10] [Batch  30/178] [E loss: 1.484226]
# [Epoch  2/10] [Batch  35/178] [E loss: 1.497907]
# [Epoch  2/10] [Batch  40/178] [E loss: 1.487800]
# [Epoch  2/10] [Batch  45/178] [E loss: 1.481998]
# [Epoch  2/10] [Batch  50/178] [E loss: 1.509959]
# [Epoch  2/10] [Batch  55/178] [E loss: 1.478702]
# [Epoch  2/10] [Batch  60/178] [E loss: 1.484761]
# [Epoch  2/10] [Batch  65/178] [E loss: 1.495768]
# [Epoch  2/10] [Batch  70/178] [E loss: 1.495135]
# [Epoch  2/10] [Batch  75/178] [E loss: 1.469961]
# [Epoch  2/10] [Batch  80/178] [E loss: 1.476691]
# [Epoch  2/10] [Batch  85/178] [E loss: 1.482108]
# [Epoch  2/10] [Batch  90/178] [E loss: 1.469915]
# [Epoch  2/10] [Batch  95/178] [E loss: 1.484164]
# [Epoch  2/10] [Batch 100/178] [E loss: 1.485909]
# [Epoch  2/10] [Batch 105/178] [E loss: 1.475772]
# [Epoch  2/10] [Batch 110/178] [E loss: 1.478927]
# [Epoch  2/10] [Batch 115/178] [E loss: 1.472335]
# [Epoch  2/10] [Batch 120/178] [E loss: 1.481834]
# [Epoch  2/10] [Batch 125/178] [E loss: 1.478026]
# [Epoch  2/10] [Batch 130/178] [E loss: 1.474022]
# [Epoch  2/10] [Batch 135/178] [E loss: 1.476456]
# [Epoch  2/10] [Batch 140/178] [E loss: 1.495017]
# [Epoch  2/10] [Batch 145/178] [E loss: 1.489595]
# [Epoch  2/10] [Batch 150/178] [E loss: 1.493165]
# [Epoch  2/10] [Batch 155/178] [E loss: 1.483927]
# [Epoch  2/10] [Batch 160/178] [E loss: 1.479454]
# [Epoch  2/10] [Batch 165/178] [E loss: 1.468668]
# [Epoch  2/10] [Batch 170/178] [E loss: 1.484906]
# [Epoch  2/10] [Batch 175/178] [E loss: 1.487092]
# [Epoch  3/10] [Batch   0/178] [E loss: 1.508113]
# [Epoch  3/10] [Batch   5/178] [E loss: 1.485604]
# [Epoch  3/10] [Batch  10/178] [E loss: 1.488689]
# [Epoch  3/10] [Batch  15/178] [E loss: 1.473547]
# [Epoch  3/10] [Batch  20/178] [E loss: 1.467571]
# [Epoch  3/10] [Batch  25/178] [E loss: 1.486738]
# [Epoch  3/10] [Batch  30/178] [E loss: 1.473908]
# [Epoch  3/10] [Batch  35/178] [E loss: 1.484747]
# [Epoch  3/10] [Batch  40/178] [E loss: 1.492167]
# [Epoch  3/10] [Batch  45/178] [E loss: 1.478045]
# [Epoch  3/10] [Batch  50/178] [E loss: 1.473400]
# [Epoch  3/10] [Batch  55/178] [E loss: 1.471896]
# [Epoch  3/10] [Batch  60/178] [E loss: 1.497744]
# [Epoch  3/10] [Batch  65/178] [E loss: 1.465651]
# [Epoch  3/10] [Batch  70/178] [E loss: 1.486444]
# [Epoch  3/10] [Batch  75/178] [E loss: 1.477846]
# [Epoch  3/10] [Batch  80/178] [E loss: 1.457705]
# [Epoch  3/10] [Batch  85/178] [E loss: 1.468048]
# [Epoch  3/10] [Batch  90/178] [E loss: 1.465950]
# [Epoch  3/10] [Batch  95/178] [E loss: 1.473531]
# [Epoch  3/10] [Batch 100/178] [E loss: 1.468846]
# [Epoch  3/10] [Batch 105/178] [E loss: 1.467440]
# [Epoch  3/10] [Batch 110/178] [E loss: 1.471195]
# [Epoch  3/10] [Batch 115/178] [E loss: 1.478092]
# [Epoch  3/10] [Batch 120/178] [E loss: 1.458934]
# [Epoch  3/10] [Batch 125/178] [E loss: 1.477225]
# [Epoch  3/10] [Batch 130/178] [E loss: 1.491468]
# [Epoch  3/10] [Batch 135/178] [E loss: 1.481563]
# [Epoch  3/10] [Batch 140/178] [E loss: 1.486038]
# [Epoch  3/10] [Batch 145/178] [E loss: 1.474073]
# [Epoch  3/10] [Batch 150/178] [E loss: 1.490996]
# [Epoch  3/10] [Batch 155/178] [E loss: 1.481857]
# [Epoch  3/10] [Batch 160/178] [E loss: 1.478031]
# [Epoch  3/10] [Batch 165/178] [E loss: 1.470740]
# [Epoch  3/10] [Batch 170/178] [E loss: 1.474134]
# [Epoch  3/10] [Batch 175/178] [E loss: 1.466250]
# [Epoch  4/10] [Batch   0/178] [E loss: 1.450989]
# [Epoch  4/10] [Batch   5/178] [E loss: 1.469399]
# [Epoch  4/10] [Batch  10/178] [E loss: 1.473092]
# [Epoch  4/10] [Batch  15/178] [E loss: 1.468007]
# [Epoch  4/10] [Batch  20/178] [E loss: 1.462749]
# [Epoch  4/10] [Batch  25/178] [E loss: 1.454150]
# [Epoch  4/10] [Batch  30/178] [E loss: 1.467126]
# [Epoch  4/10] [Batch  35/178] [E loss: 1.474030]
# [Epoch  4/10] [Batch  40/178] [E loss: 1.457177]
# [Epoch  4/10] [Batch  45/178] [E loss: 1.475695]
# [Epoch  4/10] [Batch  50/178] [E loss: 1.486132]
# [Epoch  4/10] [Batch  55/178] [E loss: 1.470914]
# [Epoch  4/10] [Batch  60/178] [E loss: 1.467927]
# [Epoch  4/10] [Batch  65/178] [E loss: 1.469594]
# [Epoch  4/10] [Batch  70/178] [E loss: 1.475317]
# [Epoch  4/10] [Batch  75/178] [E loss: 1.497962]
# [Epoch  4/10] [Batch  80/178] [E loss: 1.474770]
# [Epoch  4/10] [Batch  85/178] [E loss: 1.477571]
# [Epoch  4/10] [Batch  90/178] [E loss: 1.473097]
# [Epoch  4/10] [Batch  95/178] [E loss: 1.477723]
# [Epoch  4/10] [Batch 100/178] [E loss: 1.477326]
# [Epoch  4/10] [Batch 105/178] [E loss: 1.480708]
# [Epoch  4/10] [Batch 110/178] [E loss: 1.468316]
# [Epoch  4/10] [Batch 115/178] [E loss: 1.485383]
# [Epoch  4/10] [Batch 120/178] [E loss: 1.460625]
# [Epoch  4/10] [Batch 125/178] [E loss: 1.476565]
# [Epoch  4/10] [Batch 130/178] [E loss: 1.459318]
# [Epoch  4/10] [Batch 135/178] [E loss: 1.474873]
# [Epoch  4/10] [Batch 140/178] [E loss: 1.477097]
# [Epoch  4/10] [Batch 145/178] [E loss: 1.462238]
# [Epoch  4/10] [Batch 150/178] [E loss: 1.464573]
# [Epoch  4/10] [Batch 155/178] [E loss: 1.472029]
# [Epoch  4/10] [Batch 160/178] [E loss: 1.465166]
# [Epoch  4/10] [Batch 165/178] [E loss: 1.477754]
# [Epoch  4/10] [Batch 170/178] [E loss: 1.482108]
# [Epoch  4/10] [Batch 175/178] [E loss: 1.470423]
# [Epoch  5/10] [Batch   0/178] [E loss: 1.470293]
# [Epoch  5/10] [Batch   5/178] [E loss: 1.466593]
# [Epoch  5/10] [Batch  10/178] [E loss: 1.477552]
# [Epoch  5/10] [Batch  15/178] [E loss: 1.467952]
# [Epoch  5/10] [Batch  20/178] [E loss: 1.464205]
# [Epoch  5/10] [Batch  25/178] [E loss: 1.473140]
# [Epoch  5/10] [Batch  30/178] [E loss: 1.469390]
# [Epoch  5/10] [Batch  35/178] [E loss: 1.458111]
# [Epoch  5/10] [Batch  40/178] [E loss: 1.482805]
# [Epoch  5/10] [Batch  45/178] [E loss: 1.472856]
# [Epoch  5/10] [Batch  50/178] [E loss: 1.469955]
# [Epoch  5/10] [Batch  55/178] [E loss: 1.469830]
# [Epoch  5/10] [Batch  60/178] [E loss: 1.460669]
# [Epoch  5/10] [Batch  65/178] [E loss: 1.454463]
# [Epoch  5/10] [Batch  70/178] [E loss: 1.486198]
# [Epoch  5/10] [Batch  75/178] [E loss: 1.461667]
# [Epoch  5/10] [Batch  80/178] [E loss: 1.482900]
# [Epoch  5/10] [Batch  85/178] [E loss: 1.466673]
# [Epoch  5/10] [Batch  90/178] [E loss: 1.462837]
# [Epoch  5/10] [Batch  95/178] [E loss: 1.463221]
# [Epoch  5/10] [Batch 100/178] [E loss: 1.456806]
# [Epoch  5/10] [Batch 105/178] [E loss: 1.467742]
# [Epoch  5/10] [Batch 110/178] [E loss: 1.456769]
# [Epoch  5/10] [Batch 115/178] [E loss: 1.464592]
# [Epoch  5/10] [Batch 120/178] [E loss: 1.488123]
# [Epoch  5/10] [Batch 125/178] [E loss: 1.459378]
# [Epoch  5/10] [Batch 130/178] [E loss: 1.464234]
# [Epoch  5/10] [Batch 135/178] [E loss: 1.465930]
# [Epoch  5/10] [Batch 140/178] [E loss: 1.468670]
# [Epoch  5/10] [Batch 145/178] [E loss: 1.472914]
# [Epoch  5/10] [Batch 150/178] [E loss: 1.483642]
# [Epoch  5/10] [Batch 155/178] [E loss: 1.471937]
# [Epoch  5/10] [Batch 160/178] [E loss: 1.480506]
# [Epoch  5/10] [Batch 165/178] [E loss: 1.468388]
# [Epoch  5/10] [Batch 170/178] [E loss: 1.469732]
# [Epoch  5/10] [Batch 175/178] [E loss: 1.462844]
# [Epoch  6/10] [Batch   0/178] [E loss: 1.488001]
# [Epoch  6/10] [Batch   5/178] [E loss: 1.473728]
# [Epoch  6/10] [Batch  10/178] [E loss: 1.473740]
# [Epoch  6/10] [Batch  15/178] [E loss: 1.452121]
# [Epoch  6/10] [Batch  20/178] [E loss: 1.465473]
# [Epoch  6/10] [Batch  25/178] [E loss: 1.473875]
# [Epoch  6/10] [Batch  30/178] [E loss: 1.472000]
# [Epoch  6/10] [Batch  35/178] [E loss: 1.477690]
# [Epoch  6/10] [Batch  40/178] [E loss: 1.470650]
# [Epoch  6/10] [Batch  45/178] [E loss: 1.486281]
# [Epoch  6/10] [Batch  50/178] [E loss: 1.447070]
# [Epoch  6/10] [Batch  55/178] [E loss: 1.463576]
# [Epoch  6/10] [Batch  60/178] [E loss: 1.473054]
# [Epoch  6/10] [Batch  65/178] [E loss: 1.475675]
# [Epoch  6/10] [Batch  70/178] [E loss: 1.469644]
# [Epoch  6/10] [Batch  75/178] [E loss: 1.487536]
# [Epoch  6/10] [Batch  80/178] [E loss: 1.465327]
# [Epoch  6/10] [Batch  85/178] [E loss: 1.462621]
# [Epoch  6/10] [Batch  90/178] [E loss: 1.467973]
# [Epoch  6/10] [Batch  95/178] [E loss: 1.452276]
# [Epoch  6/10] [Batch 100/178] [E loss: 1.450908]
# [Epoch  6/10] [Batch 105/178] [E loss: 1.462876]
# [Epoch  6/10] [Batch 110/178] [E loss: 1.464003]
# [Epoch  6/10] [Batch 115/178] [E loss: 1.468550]
# [Epoch  6/10] [Batch 120/178] [E loss: 1.458593]
# [Epoch  6/10] [Batch 125/178] [E loss: 1.466392]
# [Epoch  6/10] [Batch 130/178] [E loss: 1.468374]
# [Epoch  6/10] [Batch 135/178] [E loss: 1.469358]
# [Epoch  6/10] [Batch 140/178] [E loss: 1.475662]
# [Epoch  6/10] [Batch 145/178] [E loss: 1.454320]
# [Epoch  6/10] [Batch 150/178] [E loss: 1.459364]
# [Epoch  6/10] [Batch 155/178] [E loss: 1.463814]
# [Epoch  6/10] [Batch 160/178] [E loss: 1.480186]
# [Epoch  6/10] [Batch 165/178] [E loss: 1.453630]
# [Epoch  6/10] [Batch 170/178] [E loss: 1.443422]
# [Epoch  6/10] [Batch 175/178] [E loss: 1.452774]
# [Epoch  7/10] [Batch   0/178] [E loss: 1.478804]
# [Epoch  7/10] [Batch   5/178] [E loss: 1.469450]
# [Epoch  7/10] [Batch  10/178] [E loss: 1.478096]
# [Epoch  7/10] [Batch  15/178] [E loss: 1.472117]
# [Epoch  7/10] [Batch  20/178] [E loss: 1.472048]
# [Epoch  7/10] [Batch  25/178] [E loss: 1.468370]
# [Epoch  7/10] [Batch  30/178] [E loss: 1.460395]
# [Epoch  7/10] [Batch  35/178] [E loss: 1.471886]
# [Epoch  7/10] [Batch  40/178] [E loss: 1.456545]
# [Epoch  7/10] [Batch  45/178] [E loss: 1.451457]
# [Epoch  7/10] [Batch  50/178] [E loss: 1.477459]
# [Epoch  7/10] [Batch  55/178] [E loss: 1.457983]
# [Epoch  7/10] [Batch  60/178] [E loss: 1.475059]
# [Epoch  7/10] [Batch  65/178] [E loss: 1.464459]
# [Epoch  7/10] [Batch  70/178] [E loss: 1.460652]
# [Epoch  7/10] [Batch  75/178] [E loss: 1.460232]
# [Epoch  7/10] [Batch  80/178] [E loss: 1.473194]
# [Epoch  7/10] [Batch  85/178] [E loss: 1.465173]
# [Epoch  7/10] [Batch  90/178] [E loss: 1.463404]
# [Epoch  7/10] [Batch  95/178] [E loss: 1.461747]
# [Epoch  7/10] [Batch 100/178] [E loss: 1.488482]
# [Epoch  7/10] [Batch 105/178] [E loss: 1.466514]
# [Epoch  7/10] [Batch 110/178] [E loss: 1.457533]
# [Epoch  7/10] [Batch 115/178] [E loss: 1.456640]
# [Epoch  7/10] [Batch 120/178] [E loss: 1.457091]
# [Epoch  7/10] [Batch 125/178] [E loss: 1.467148]
# [Epoch  7/10] [Batch 130/178] [E loss: 1.451110]
# [Epoch  7/10] [Batch 135/178] [E loss: 1.472735]
# [Epoch  7/10] [Batch 140/178] [E loss: 1.465078]
# [Epoch  7/10] [Batch 145/178] [E loss: 1.454103]
# [Epoch  7/10] [Batch 150/178] [E loss: 1.465928]
# [Epoch  7/10] [Batch 155/178] [E loss: 1.464931]
# [Epoch  7/10] [Batch 160/178] [E loss: 1.463278]
# [Epoch  7/10] [Batch 165/178] [E loss: 1.479234]
# [Epoch  7/10] [Batch 170/178] [E loss: 1.458081]
# [Epoch  7/10] [Batch 175/178] [E loss: 1.467092]
# [Epoch  8/10] [Batch   0/178] [E loss: 1.459575]
# [Epoch  8/10] [Batch   5/178] [E loss: 1.473185]
# [Epoch  8/10] [Batch  10/178] [E loss: 1.466182]
# [Epoch  8/10] [Batch  15/178] [E loss: 1.454539]
# [Epoch  8/10] [Batch  20/178] [E loss: 1.471018]
# [Epoch  8/10] [Batch  25/178] [E loss: 1.482230]
# [Epoch  8/10] [Batch  30/178] [E loss: 1.467788]
# [Epoch  8/10] [Batch  35/178] [E loss: 1.455253]
# [Epoch  8/10] [Batch  40/178] [E loss: 1.457944]
# [Epoch  8/10] [Batch  45/178] [E loss: 1.449605]
# [Epoch  8/10] [Batch  50/178] [E loss: 1.461154]
# [Epoch  8/10] [Batch  55/178] [E loss: 1.469698]
# [Epoch  8/10] [Batch  60/178] [E loss: 1.485888]
# [Epoch  8/10] [Batch  65/178] [E loss: 1.458526]
# [Epoch  8/10] [Batch  70/178] [E loss: 1.462860]
# [Epoch  8/10] [Batch  75/178] [E loss: 1.480632]
# [Epoch  8/10] [Batch  80/178] [E loss: 1.442921]
# [Epoch  8/10] [Batch  85/178] [E loss: 1.460105]
# [Epoch  8/10] [Batch  90/178] [E loss: 1.464651]
# [Epoch  8/10] [Batch  95/178] [E loss: 1.459206]
# [Epoch  8/10] [Batch 100/178] [E loss: 1.464410]
# [Epoch  8/10] [Batch 105/178] [E loss: 1.450905]
# [Epoch  8/10] [Batch 110/178] [E loss: 1.457461]
# [Epoch  8/10] [Batch 115/178] [E loss: 1.451299]
# [Epoch  8/10] [Batch 120/178] [E loss: 1.463004]
# [Epoch  8/10] [Batch 125/178] [E loss: 1.474557]
# [Epoch  8/10] [Batch 130/178] [E loss: 1.454606]
# [Epoch  8/10] [Batch 135/178] [E loss: 1.456763]
# [Epoch  8/10] [Batch 140/178] [E loss: 1.457459]
# [Epoch  8/10] [Batch 145/178] [E loss: 1.461950]
# [Epoch  8/10] [Batch 150/178] [E loss: 1.456444]
# [Epoch  8/10] [Batch 155/178] [E loss: 1.473731]
# [Epoch  8/10] [Batch 160/178] [E loss: 1.481435]
# [Epoch  8/10] [Batch 165/178] [E loss: 1.469410]
# [Epoch  8/10] [Batch 170/178] [E loss: 1.473497]
# [Epoch  8/10] [Batch 175/178] [E loss: 1.453859]
# [Epoch  9/10] [Batch   0/178] [E loss: 1.466984]
# [Epoch  9/10] [Batch   5/178] [E loss: 1.459937]
# [Epoch  9/10] [Batch  10/178] [E loss: 1.447323]
# [Epoch  9/10] [Batch  15/178] [E loss: 1.486289]
# [Epoch  9/10] [Batch  20/178] [E loss: 1.463508]
# [Epoch  9/10] [Batch  25/178] [E loss: 1.461793]
# [Epoch  9/10] [Batch  30/178] [E loss: 1.472194]
# [Epoch  9/10] [Batch  35/178] [E loss: 1.461856]
# [Epoch  9/10] [Batch  40/178] [E loss: 1.453549]
# [Epoch  9/10] [Batch  45/178] [E loss: 1.457571]
# [Epoch  9/10] [Batch  50/178] [E loss: 1.461157]
# [Epoch  9/10] [Batch  55/178] [E loss: 1.457317]
# [Epoch  9/10] [Batch  60/178] [E loss: 1.450509]
# [Epoch  9/10] [Batch  65/178] [E loss: 1.478786]
# [Epoch  9/10] [Batch  70/178] [E loss: 1.464790]
# [Epoch  9/10] [Batch  75/178] [E loss: 1.452975]
# [Epoch  9/10] [Batch  80/178] [E loss: 1.473372]
# [Epoch  9/10] [Batch  85/178] [E loss: 1.463256]
# [Epoch  9/10] [Batch  90/178] [E loss: 1.462702]
# [Epoch  9/10] [Batch  95/178] [E loss: 1.462388]
# [Epoch  9/10] [Batch 100/178] [E loss: 1.442631]
# [Epoch  9/10] [Batch 105/178] [E loss: 1.463487]
# [Epoch  9/10] [Batch 110/178] [E loss: 1.451509]
# [Epoch  9/10] [Batch 115/178] [E loss: 1.449231]
# [Epoch  9/10] [Batch 120/178] [E loss: 1.474966]
# [Epoch  9/10] [Batch 125/178] [E loss: 1.451891]
# [Epoch  9/10] [Batch 130/178] [E loss: 1.455319]
# [Epoch  9/10] [Batch 135/178] [E loss: 1.472001]
# [Epoch  9/10] [Batch 140/178] [E loss: 1.470007]
# [Epoch  9/10] [Batch 145/178] [E loss: 1.459029]
# [Epoch  9/10] [Batch 150/178] [E loss: 1.468620]
# [Epoch  9/10] [Batch 155/178] [E loss: 1.462207]
# [Epoch  9/10] [Batch 160/178] [E loss: 1.470400]
# [Epoch  9/10] [Batch 165/178] [E loss: 1.445880]
# [Epoch  9/10] [Batch 170/178] [E loss: 1.460726]
# [Epoch  9/10] [Batch 175/178] [E loss: 1.441629]
# Finished Training

# %%
z = torch.randn(64, latent_dim, 1, 1).to(device) # 64, 100
fake_imgs = G(z) # 64, 1, 28, 28
fake_z = E(fake_imgs) #64, 100
reconfiguration_imgs = G(fake_z)

imshow_grid(reconfiguration_imgs)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (3, 242, 242)

# %%
# test_dataset = val_df.drop(['ID','V8','V22'],axis=1)
# # test_dataset = val_df
# val_df.rename(columns={'Class':'targets'},inplace=True)

# ls2 = []
# col = val_df.columns[:-1]

# for i in test_dataset[test_dataset['targets']!=0].apply(lambda x : [x[i] for i in col],axis=1):
#     ls = []
#     for j in i:
#         ls.append(np.array(i)*j)
#     ls2.append(ls)


# x_test = torch.FloatTensor(ls2)
# y_test = torch.FloatTensor(val_df[val_df['targets']!=0]['targets'].to_list())

# test_mnist = SimpleDataset(x_test, y_test,
#                             transform=transforms.Compose(
#                             [transforms.ToPILImage(),
#                             transforms.ToTensor(),
#                             transforms.Normalize([0.5], [0.5])])
#                             )

# test_dataloader = DataLoader(test_mnist, batch_size=1, shuffle=True)

# %%
# test_dataset = val_df.drop(['ID','V8','V22'],axis=1)
val_df.rename(columns={'Class':'targets'},inplace=True)
test_dataset = pd.concat([val_df[val_df['targets']==0][:50], val_df[val_df['targets']==1]])

ls2 = []
col = val_df.columns[:-1]

for i in test_dataset.apply(lambda x : [x[i] for i in col],axis=1):
    ls = []
    for j in i:
        ls.append(np.array(i)*j)
    ls2.append(ls)


x_test = torch.FloatTensor(ls2)
y_test = torch.FloatTensor(test_dataset['targets'].to_list())

test_mnist = SimpleDataset(x_test, y_test,
                            transform=transforms.Compose(
                            [transforms.ToPILImage(),
                            transforms.ToTensor(),
                            transforms.Normalize([0.5], [0.5])])
                            )

test_dataloader = DataLoader(test_mnist, batch_size=1, shuffle=True)

# %%
def compare_images(real_img, generated_img, i, score, reverse=False, threshold=50):
    real_img = real_img.cpu().data.numpy().reshape(28, 28) * 255
    generated_img = generated_img.cpu().data.numpy().reshape(28, 28) * 255

    negative = np.zeros_like(real_img)

    if not reverse:
        diff_img = real_img - generated_img
    else:
        diff_img = generated_img - real_img
    
    diff_img[diff_img <= threshold] = 0

    anomaly_img = np.zeros(shape=(28, 28, 3))
    anomaly_img[:, :, 0] = real_img - diff_img
    anomaly_img[:, :, 1] = real_img - diff_img
    anomaly_img[:, :, 2] = real_img - diff_img
    anomaly_img[:, :, 0] = anomaly_img[:,:,0] + diff_img
    anomaly_img = anomaly_img.astype(np.uint8)

    fig, plots = plt.subplots(1, 4)
    fig.suptitle(f'Anomaly - (anomaly score: {score:.4})')
    
    fig.set_figwidth(9)
    fig.set_tight_layout(True)
    plots = plots.reshape(-1)
    plots[0].imshow(real_img, cmap='gray', label='real')
    plots[1].imshow(generated_img, cmap='gray')
    plots[2].imshow(diff_img, cmap='gray')
    plots[3].imshow(anomaly_img)
    
    plots[0].set_title('real')
    plots[1].set_title('generated')
    plots[2].set_title('difference')
    plots[3].set_title('Anomaly Detection')
    plt.show()

# %%
criterion = nn.MSELoss()
G.eval()
D.eval()
E.eval()

with open("score.csv", "w") as f:
        f.write("label,img_distance,anomaly_score,z_distance\n")

for i, (img, label) in enumerate(test_dataloader):
    real_img = img.to(device)

    real_z = E(real_img) # 진짜 이미지의 latent vector
    fake_img = G(real_z) # G에 넣어서 가짜 이미지 생성.
    fake_z = E(fake_img) # torch.Size([1, 100]) --> latent 진짜 이미지와 매핑된 가짜 이미지의 latent vector

    real_feature = D.forward_features(real_img) # 1, 256
    fake_feature = D.forward_features(fake_img)
    real_feature = real_feature / real_feature.max()
    fake_feature = fake_feature / fake_feature.max()
    # print("real_feature max : ",real_feature.max())
    # print("real_feature min : ",real_feature.min())
    # print("fake_feature max : ",fake_feature.max())
    # print("fake_feature min : ",fake_feature.min())

    img_distance = criterion(fake_img, real_img)
    loss_feature = criterion(fake_feature, real_feature)

    anomaly_score = img_distance + kappa*loss_feature

    z_distance = criterion(fake_z, real_z)
    
    with open("score.csv", "a") as f:
            f.write(f"{label.item()},{img_distance},"
                    f"{anomaly_score},{z_distance}\n")
    
    if i % 2000 == 0:
        print(f"{label.item()}, {img_distance}, "
          f"{anomaly_score}, {z_distance}\n")
        compare_images(real_img, fake_img,i, anomaly_score, reverse = False, threshold = 80)
# Out:
# 1.0, 0.583031415939331, 0.6371160745620728, 0.07168427109718323

# %%
df = pd.read_csv("score.csv")
df
# Out:
#     label  img_distance  anomaly_score  z_distance
# 0     1.0      0.583031       0.637116    0.071684
# 1     0.0      0.899413       0.949839    0.217825
# 2     1.0      0.606634       0.658640    0.046970
# 3     0.0      0.867515       0.906598    0.233118
# 4     0.0      0.556491       0.596901    0.097778
# ..    ...           ...            ...         ...
# 75    1.0      0.576751       0.643670    0.085685
# 76    0.0      0.789337       0.837342    0.172449
# 77    0.0      0.823078       0.906756    0.104528
# 78    1.0      0.566658       0.625963    0.067005
# 79    0.0      0.780780       0.854281    0.102179
#
# [80 rows x 4 columns]

# %%
trainig_label = 1
labels = np.where(df["label"].values == trainig_label, 0, 1) # 라벨이 1이면 0을 반환, 아니면 1을 반환.
anomaly_score = df["anomaly_score"].values
img_distance = df["img_distance"].values
z_distance = df["z_distance"].values

# %%
from sklearn.metrics import roc_curve, precision_recall_curve, auc

fpr, tpr, _ = roc_curve(labels, img_distance)
precision, recall, _ = precision_recall_curve(labels, img_distance)
roc_auc = auc(fpr, tpr)
pr_auc =  auc(recall, precision)

# %%
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:3f}")
plt.plot([0, 1], [0, 1], linestyle="--")
plt.title("ROC-AUC")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.show()

# %%
plt.hist([anomaly_score[labels == 0], anomaly_score[labels == 1]],
          bins=100, density=True, stacked=True,
          label=["Normal", "Abnormal"])
plt.title("Discrete distributions of anomaly scores")
plt.xlabel("Anomaly scores A(x)")
plt.ylabel("h")
plt.legend()
plt.show()
